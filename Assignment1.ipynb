# %% [markdown]
# Q1. Why do we call Python as a general purpose and high-level programming language?

# %% [markdown]
# Ans :
# Python is general purpose programming because it is capable of creating all types of programs and it is not domain specific language.
# Python is high level langauge beacuse it is an interpreted language which will be compiled first (means converts into low level langauge) and that low level langauge executed in the processor and also easy to read and implement..

# %% [markdown]
# Q2. Why is Python called a dynamically typed language?

# %% [markdown]
# Ans : Because , interpreter assigns the type of the variable at run-time based upon the variable value.

# %% [markdown]
# Q3.List some pros and cons of Python programming language?

# %% [markdown]
# Ans:
#
# pros:<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code> Python is beginner friendly , it is easy to learn and implement .<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>It has large community.<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>It has extensive libraries which makes you to build easily.<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>In many technologies like data science , big data etc. , python is most preferable langauge to implement these technologies and having large community in that areas.<br>
# Cons:<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    It consumes more power compared to java , c,c++.<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    It is slower compare to java , c , c++.<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    It is dynamical typed langauge , slower compared with java , c,c++.<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>   Multithreading in Python is not exactly true multithreading due to its global interpreter lock.<br>

# %% [markdown]
# Q4. In what all domains can we use Python?
#
# Ans : Now-a-days , most of the technologies using python ,
# Data Science , Big data , Web development , Automation , Internet of things..

# %% [markdown]
# Q5. What are variable and how can we declare them?
#
# ANs: variable is name that is refernce or pointer of an object. In python , we can declare variable name with value assignment.

# %% [markdown]
# Q6. How can we take an input from the user in Python?
#
# Ans : Using input() built in method for taking the user input.

# %% [markdown]
# Q7. What is the default datatype of the value that has been taken as an input using input() function?
#
# Ans : String data-type.

# %% [markdown]
# Q8. What is type casting?
#
# And: Type casting is nothing but to convert variable data type into another data type either implicitly or explicitly.

# %% [markdown]
# Q9. Can we take more than one input from the user using single input() function? If yes, how? If no, why?
#
# Ans : No , we can't take more than one input (here more than one input means single line input) , but we can convert that single line into multiple inputs.

# %% [markdown]
# Q10. What are keywords?
#
# Ans : Python has a set of keywords that are reserved words that cannot be used as variable names, function names, or any other identifiers.
# Every keyword has specify utility in every programming langauge.

# %% [markdown]
# Q11. Can we use keywords as a variable? Support your answer with reason.
#
# ANs : No , we don't use keywords as a variable , if you use keyword as variable , it lose its utility.
# In some langauges , it raises error , in python , we can do , but it lose its utility.

# %% [markdown]
# Q12. What is indentation? What's the use of indentaion in Python?
#
# Ans : Indentation refers to the spaces at the beginning of a code line. Identation uses to define the block of statements in python .

# %% [markdown]
# Q13. How can we throw some output in Python?
#
# Ans : using print , we can throw the output in python

# %% [markdown]
# Q14. What are operators in Python?
#
# Operators in python:<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    1. arthimetic operators (+,-,*,/,//,%).<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    2. assignment operators (=,+=,-=,/=,*=).<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    3. Bitwise operators (&,|,^).<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    4. comparison operators(==,!=,>=,<=).<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code> 5. logical operators (and,or,not)<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    6. Membership operators (in,not in)<br>
# <code>&nbsp;&nbsp;&nbsp;&nbsp;</code>    7. Identity operators (is,is not)<br>

# %% [markdown]
# Q15. What is difference between / and // operators?
#
# / is float division , // is integer division or floor division.

# %% [markdown]
# Q16. Write a code that gives following as an output.
# ```
# iNeuroniNeuroniNeuroniNeuron
# ```
#
# Ans:

# %%
print('iNeuron'*4)
# Out:
# iNeuroniNeuroniNeuroniNeuron

# %% [markdown]
# Q17. Write a code to take a number as an input from the user and check if the number is odd or even.

# %%
try:
    n = int(input('Emter number : '))
    if n%2==0:
        print('Number is even')
    else:
        print('Number is odd')
except:
    print('please enter integer')
# Out:
# Emter number : 15
# Number is odd

# %% [markdown]
# Q18. What are boolean operator?
#
# Ans : Boolean operators are those that take Boolean inputs and return Boolean results.
# Since Python Boolean values have only two possible options, True or False, it’s possible to specify the operators completely in terms of the results they assign to every possible input combination. These specifications are called truth tables since they’re displayed in a table.

# %% [markdown]
# Q19. What will the output of the following?
# ```
# 1 or 0
#
# 0 and 0
#
# True and False and True
#
# 1 or 0 or 0
# ```
#
# Ans:
#
# 1 or 0 --> 1
#
# 0 and 0 --> 0
#
# True and False and True --> False
#
# 1 or 0 or 0 --> 1

# %% [markdown]
# Q20. What are conditional statements in Python?
#
# Ans : Conditional statements in python are if , elif and else. Usually conditional statements are using for checking particular scenarios.
# for example using if statement , we have one condition if it is true , it executes the if block otherwise it executes the else block.

# %% [markdown]
# Q21. What is use of 'if', 'elif' and 'else' keywords?
#
# Ans:
#
# 'if' -- it is the first thing for starting the conditional statements , usually it check the if condition first , then it will executes the particualr code.
#
# 'elif' --  if we have more than one condition to check , we use elif for checking all conditions.
#
# 'else' -- it is last part , if any conditions doesn't satisfy , it uses else block to execute.

# %% [markdown]
# Q22. Write a code to take the age of person as an input and if age >= 18 display "I can vote". If age is < 18 display "I can't vote".

# %%
age = int(input('enter the age : '))
if age>=18:
    print('I can vote')
else:
    print("I can't vote")
# Out:
# enter the age : 18
# I can vote

# %% [markdown]
# Q23. Write a code that displays the sum of all the even numbers from the given list.
# ```
# numbers = [12, 75, 150, 180, 145, 525, 50]
# ```

# %%
total = 0 
numbers = [12, 75, 150, 180, 145, 525, 50]

for i in numbers:
    if i%2==0:
        total+=i
print(total)
# Out:
# 392

# %% [markdown]
# Q24. Write a code to take 3 numbers as an input from the user and display the greatest no as output.

# %%
a,b,c = map(int,input().split())

print(max([a,b,c]))
# Out:
# 23 45 34
# 45

# %% [markdown]
# Q25. Write a program to display only those numbers from a list that satisfy the following conditions
#
# - The number must be divisible by five
#
# - If the number is greater than 150, then skip it and move to the next number
#
# - If the number is greater than 500, then stop the loop
# ```
# numbers = [12, 75, 150, 180, 145, 525, 50]
# ```

# %%
numbers = [12, 75, 150, 180, 145, 525, 50]

for i in numbers:
    if i>150:
        continue
    elif i>500:
        break
    elif i%5==0:
        print(i)
# Out:
# 75
# 150
# 145
# 50
